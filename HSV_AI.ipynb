# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
signatures_url = '/gdrive/MyDrive/HandwritenSignatureAI/DataScience/Input/'

# %%
# %cd MyDrive/HandwritenSignatureAI/DataScience/Input/
# !ls
# Out:
# /gdrive/MyDrive/HandwritenSignatureAI/DataScience/Input
# sign_data

# %%
test= signatures_url+'sign_data/test_data.csv'
test
# Out:
# '/gdrive/MyDrive/HandwritenSignatureAI/DataScience/Input/sign_data/test_data.csv'

# %%
pd.read_csv(test)
# Out:
#       068/09_068.png  068_forg/03_0113068.PNG  1
# 0     068/09_068.png  068_forg/01_0124068.PNG  1
# 1     068/09_068.png  068_forg/02_0124068.PNG  1
# 2     068/09_068.png  068_forg/01_0113068.PNG  1
# 3     068/09_068.png  068_forg/04_0124068.PNG  1
# 4     068/09_068.png  068_forg/04_0113068.PNG  1
# ...              ...                      ... ..
# 5742  066/01_066.png           066/06_066.png  0
# 5743  066/01_066.png           066/08_066.png  0
# 5744  066/01_066.png           066/02_066.png  0
# 5745  066/01_066.png           066/05_066.png  0
# 5746  066/01_066.png           066/11_066.png  0
#
# [5747 rows x 3 columns]
