# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

# %% [markdown]
# Additional Utility Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/MyDrive/HandwritenSignatureAI/DataScience
# Out:
# /gdrive/MyDrive/HandwritenSignatureAI/DataScience

# %%
# First, look at everything.
from subprocess import check_output
print(check_output(["ls", "./Input/sign_data"]).decode("utf8"))
# Out:
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = "./Input/sign_data/train"
    testing_dir = "./Input/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 50

# %% [markdown]
# Load Dataset :
#
# Dataset is loaded in gdrive.

# %%
training_dir="./Input/sign_data/train"
training_csv="./Input/sign_data/train_data.csv"
testing_csv="./Input/sign_data/test_data.csv"
testing_dir="./Input/sign_data/test"

# %% [markdown]
# #Preprocessing and Loading Dataset
#
# We preprocessed all the images and loaded them as .npy files which is easy to **transfer** . You can follow your own preprocessing steps

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [1.]
#  [0.]]

# %% [markdown]
# #Siamese Network Definition

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            
            nn.Conv2d(1, 96, kernel_size=11,stride=1),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

            nn.Conv2d(256,384 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384,256 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

        )
        
        # Defining the fully connected layers
        self.fc1 = nn.Sequential(
            nn.Linear(30976, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.5),
            
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            
            nn.Linear(128,2))
        
  
  
    def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward_once(input1)
        # forward pass of input 2
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# Loss Function

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# Train the Model

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
# Check whether you have GPU is loaded or not
if torch.cuda.is_available():
    print('Yes')
# Out:
# Yes

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer
optimizer = optim.RMSprop(net.parameters(), lr=1e-4, alpha=0.99, eps=1e-8, weight_decay=0.0005, momentum=0.9)

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# Epoch number 0
#  Current loss 1.7425248622894287
#
# Epoch number 0
#  Current loss 1.2723283767700195
#
# Epoch number 0
#  Current loss 1.4742100238800049
#
# Epoch number 0
#  Current loss 1.1933119297027588
#
# Epoch number 0
#  Current loss 1.4021539688110352
#
# Epoch number 0
#  Current loss 1.1795519590377808
#
# Epoch number 0
#  Current loss 1.2465384006500244
#
# Epoch number 0
#  Current loss 1.2303143739700317
#
# Epoch number 0
#  Current loss 1.1906399726867676
#
# Epoch number 0
#  Current loss 1.281451940536499
#
# Epoch number 0
#  Current loss 1.1396894454956055
#
# Epoch number 0
#  Current loss 1.081848382949829
#
# Epoch number 0
#  Current loss 1.3646597862243652
#
# Epoch number 0
#  Current loss 1.231316089630127
#
# Epoch number 0
#  Current loss 1.2559534311294556
#
# Epoch number 1
#  Current loss 1.5581066608428955
#
# Epoch number 1
#  Current loss 1.215611219406128
#
# Epoch number 1
#  Current loss 1.033705234527588
#
# Epoch number 1
#  Current loss 1.432607889175415
#
# Epoch number 1
#  Current loss 1.1699023246765137
#
# Epoch number 1
#  Current loss 1.22194242477417
#
# Epoch number 1
#  Current loss 1.2084424495697021
#
# Epoch number 1
#  Current loss 1.098550796508789
#
# Epoch number 1
#  Current loss 1.400443196296692
#
# Epoch number 1
#  Current loss 1.2646204233169556
#
# Epoch number 1
#  Current loss 1.7768219709396362
#
# Epoch number 1
#  Current loss 1.3231396675109863
#
# Epoch number 1
#  Current loss 1.1894727945327759
#
# Epoch number 1
#  Current loss 1.2894415855407715
#
# Epoch number 1
#  Current loss 1.1532292366027832
#
# Epoch number 2
#  Current loss 1.469451904296875
#
# Epoch number 2
#  Current loss 1.3284249305725098
#
# Epoch number 2
#  Current loss 1.0264889001846313
#
# Epoch number 2
#  Current loss 1.2331650257110596
#
# Epoch number 2
#  Current loss 1.3468616008758545
#
# Epoch number 2
#  Current loss 0.8002387881278992
#
# Epoch number 2
#  Current loss 1.195098876953125
#
# Epoch number 2
#  Current loss 1.3996165990829468
#
# Epoch number 2
#  Current loss 1.557528018951416
#
# Epoch number 2
#  Current loss 1.7689549922943115
#
# Epoch number 2
#  Current loss 1.3920574188232422
#
# Epoch number 2
#  Current loss 1.0543407201766968
#
# Epoch number 2
#  Current loss 1.1878812313079834
#
# Epoch number 2
#  Current loss 1.1454122066497803
#
# Epoch number 2
#  Current loss 1.0348654985427856
#
# Epoch number 3
#  Current loss 1.2590550184249878
#
# Epoch number 3
#  Current loss 1.7183576822280884
#
# Epoch number 3
#  Current loss 1.1167845726013184
#
# Epoch number 3
#  Current loss 1.2397398948669434
#
# Epoch number 3
#  Current loss 1.1707682609558105
#
# Epoch number 3
#  Current loss 1.5423343181610107
#
# Epoch number 3
#  Current loss 1.101830005645752
#
# Epoch number 3
#  Current loss 1.2831063270568848
#
# Epoch number 3
#  Current loss 1.1489496231079102
#
# Epoch number 3
#  Current loss 1.1603792905807495
#
# Epoch number 3
#  Current loss 0.9196484088897705
#
# Epoch number 3
#  Current loss 1.2486844062805176
#
# Epoch number 3
#  Current loss 1.1171702146530151
#
# Epoch number 3
#  Current loss 1.287109613418579
#
# Epoch number 3
#  Current loss 1.23722243309021
#
# Epoch number 4
#  Current loss 0.9729914665222168
#
# Epoch number 4
#  Current loss 1.2361128330230713
#
# Epoch number 4
#  Current loss 1.1219669580459595
#
# Epoch number 4
#  Current loss 0.9673322439193726
#
# Epoch number 4
#  Current loss 1.2239259481430054
#
# Epoch number 4
#  Current loss 1.0763781070709229
#
# Epoch number 4
#  Current loss 1.3433815240859985
#
# Epoch number 4
#  Current loss 1.2224576473236084
#
# Epoch number 4
#  Current loss 1.128450870513916
#
# Epoch number 4
#  Current loss 1.2142930030822754
#
# Epoch number 4
#  Current loss 1.2754487991333008
#
# Epoch number 4
#  Current loss 1.277294397354126
#
# Epoch number 4
#  Current loss 1.320198655128479
#
# Epoch number 4
#  Current loss 1.1357786655426025
#
# Epoch number 4
#  Current loss 1.3436639308929443
#
# Epoch number 5
#  Current loss 1.1409502029418945
#
# Epoch number 5
#  Current loss 1.404305100440979
#
# Epoch number 5
#  Current loss 1.1460318565368652
#
# Epoch number 5
#  Current loss 1.242881417274475
#
# Epoch number 5
#  Current loss 1.2452927827835083
#
# Epoch number 5
#  Current loss 1.2132645845413208
#
# Epoch number 5
#  Current loss 1.3380141258239746
#
# Epoch number 5
#  Current loss 1.3983293771743774
#
# Epoch number 5
#  Current loss 1.239941120147705
#
# Epoch number 5
#  Current loss 1.433887004852295
#
# Epoch number 5
#  Current loss 1.290436029434204
#
# Epoch number 5
#  Current loss 1.2061595916748047
#
# Epoch number 5
#  Current loss 1.3004810810089111
#
# Epoch number 5
#  Current loss 1.1588854789733887
#
# Epoch number 5
#  Current loss 1.2341489791870117
#
# Epoch number 6
#  Current loss 1.5800859928131104
#
# Epoch number 6
#  Current loss 1.4169490337371826
#
# Epoch number 6
#  Current loss 1.212996006011963
#
# Epoch number 6
#  Current loss 1.1204824447631836
#
# Epoch number 6
#  Current loss 1.1932950019836426
#
# Epoch number 6
#  Current loss 1.2117257118225098
#
# Epoch number 6
#  Current loss 1.2077455520629883
#
# Epoch number 6
#  Current loss 1.218173623085022
#
# Epoch number 6
#  Current loss 1.1552879810333252
#
# Epoch number 6
#  Current loss 1.0925512313842773
#
# Epoch number 6
#  Current loss 1.1985507011413574
#
# Epoch number 6
#  Current loss 1.2123135328292847
#
# Epoch number 6
#  Current loss 1.2469074726104736
#
# Epoch number 6
#  Current loss 1.1533750295639038
#
# Epoch number 6
#  Current loss 1.2637088298797607
#
# Epoch number 7
#  Current loss 1.1577441692352295
#
# Epoch number 7
#  Current loss 1.232297658920288
#
# Epoch number 7
#  Current loss 1.272754192352295
#
# Epoch number 7
#  Current loss 1.196942687034607
#
# Epoch number 7
#  Current loss 1.342430830001831
#
# Epoch number 7
#  Current loss 1.146140694618225
#
# Epoch number 7
#  Current loss 1.3046655654907227
#
# Epoch number 7
#  Current loss 1.220275640487671
#
# Epoch number 7
#  Current loss 1.3334860801696777
#
# Epoch number 7
#  Current loss 1.2980378866195679
#
# Epoch number 7
#  Current loss 1.3652210235595703
#
# Epoch number 7
#  Current loss 1.181308388710022
#
# Epoch number 7
#  Current loss 1.058612585067749
#
# Epoch number 7
#  Current loss 1.2825329303741455
#
# Epoch number 7
#  Current loss 1.1046662330627441
#
# Epoch number 8
#  Current loss 1.3952770233154297
#
# Epoch number 8
#  Current loss 1.0724163055419922
#
# Epoch number 8
#  Current loss 1.1593811511993408
#
# Epoch number 8
#  Current loss 1.1876227855682373
#
# Epoch number 8
#  Current loss 1.1818413734436035
#
# Epoch number 8
#  Current loss 1.2164816856384277
#
# Epoch number 8
#  Current loss 1.347908854484558
#
# Epoch number 8
#  Current loss 1.3564155101776123
#
# Epoch number 8
#  Current loss 1.1661179065704346
#
# Epoch number 8
#  Current loss 0.9566347002983093
#
# Epoch number 8
#  Current loss 1.236128568649292
#
# Epoch number 8
#  Current loss 1.2757887840270996
#
# Epoch number 8
#  Current loss 1.2440142631530762
#
# Epoch number 8
#  Current loss 1.2055927515029907
#
# Epoch number 8
#  Current loss 1.1146399974822998
#
# Epoch number 9
#  Current loss 1.1885746717453003
#
# Epoch number 9
#  Current loss 1.1261212825775146
#
# Epoch number 9
#  Current loss 0.9079278707504272
#
# Epoch number 9
#  Current loss 1.0246295928955078
#
# Epoch number 9
#  Current loss 1.5322766304016113
#
# Epoch number 9
#  Current loss 0.9359561204910278
#
# Epoch number 9
#  Current loss 1.256150722503662
#
# Epoch number 9
#  Current loss 1.239180326461792
#
# Epoch number 9
#  Current loss 1.5824391841888428
#
# Epoch number 9
#  Current loss 1.062345027923584
#
# Epoch number 9
#  Current loss 0.9625449776649475
#
# Epoch number 9
#  Current loss 1.2439922094345093
#
# Epoch number 9
#  Current loss 1.194035530090332
#
# Epoch number 9
#  Current loss 1.0794646739959717
#
# Epoch number 9
#  Current loss 1.2329294681549072
#
# Epoch number 10
#  Current loss 1.2023231983184814
#
# Epoch number 10
#  Current loss 1.1914265155792236
#
# Epoch number 10
#  Current loss 1.1847914457321167
#
# Epoch number 10
#  Current loss 1.0564260482788086
#
# Epoch number 10
#  Current loss 0.915347695350647
#
# Epoch number 10
#  Current loss 1.128914713859558
#
# Epoch number 10
#  Current loss 1.3299236297607422
#
# Epoch number 10
#  Current loss 1.095721960067749
#
# Epoch number 10
#  Current loss 1.2992796897888184
#
# Epoch number 10
#  Current loss 1.2715551853179932
#
# Epoch number 10
#  Current loss 0.9974649548530579
#
# Epoch number 10
#  Current loss 0.9853095412254333
#
# Epoch number 10
#  Current loss 1.2844250202178955
#
# Epoch number 10
#  Current loss 1.4463896751403809
#
# Epoch number 10
#  Current loss 1.1064436435699463
#
# Epoch number 11
#  Current loss 1.1055397987365723
#
# Epoch number 11
#  Current loss 1.203369379043579
#
# Epoch number 11
#  Current loss 1.2243051528930664
#
# Epoch number 11
#  Current loss 1.218961477279663
#
# Epoch number 11
#  Current loss 1.2748744487762451
#
# Epoch number 11
#  Current loss 1.3134503364562988
#
# Epoch number 11
#  Current loss 1.0734862089157104
#
# Epoch number 11
#  Current loss 1.2135666608810425
#
# Epoch number 11
#  Current loss 1.2064255475997925
#
# Epoch number 11
#  Current loss 1.2173638343811035
#
# Epoch number 11
#  Current loss 1.3831710815429688
#
# Epoch number 11
#  Current loss 1.4619834423065186
#
# Epoch number 11
#  Current loss 1.0780084133148193
#
# Epoch number 11
#  Current loss 1.4989668130874634
#
# Epoch number 11
#  Current loss 1.4857324361801147
#
# Epoch number 12
#  Current loss 1.2761026620864868
#
# Epoch number 12
#  Current loss 1.149477481842041
#
# Epoch number 12
#  Current loss 1.0089271068572998
#
# Epoch number 12
#  Current loss 1.1693222522735596
#
# Epoch number 12
#  Current loss 1.1483635902404785
#
# Epoch number 12
#  Current loss 1.703357219696045
#
# Epoch number 12
#  Current loss 1.4451017379760742
#
# Epoch number 12
#  Current loss 1.1241233348846436
#
# Epoch number 12
#  Current loss 1.2334222793579102
#
# Epoch number 12
#  Current loss 1.0116102695465088
#
# Epoch number 12
#  Current loss 1.1531423330307007
#
# Epoch number 12
#  Current loss 1.101400375366211
#
# Epoch number 12
#  Current loss 1.1510035991668701
#
# Epoch number 12
#  Current loss 0.9860097765922546
#
# Epoch number 12
#  Current loss 1.187042236328125
#
# Epoch number 13
#  Current loss 1.2237522602081299
#
# Epoch number 13
#  Current loss 1.1000661849975586
#
# Epoch number 13
#  Current loss 1.2255563735961914
#
# Epoch number 13
#  Current loss 1.1846671104431152
#
# Epoch number 13
#  Current loss 1.1081621646881104
#
# Epoch number 13
#  Current loss 1.227693796157837
#
# Epoch number 13
#  Current loss 1.7628988027572632
#
# Epoch number 13
#  Current loss 1.1268494129180908
#
# Epoch number 13
#  Current loss 1.1860452890396118
#
# Epoch number 13
#  Current loss 1.1235361099243164
#
# Epoch number 13
#  Current loss 0.9515309929847717
#
# Epoch number 13
#  Current loss 1.1390693187713623
#
# Epoch number 13
#  Current loss 1.2397574186325073
#
# Epoch number 13
#  Current loss 1.2472983598709106
#
# Epoch number 13
#  Current loss 1.1375714540481567
#
# Epoch number 14
#  Current loss 1.2079689502716064
#
# Epoch number 14
#  Current loss 1.44917631149292
#
# Epoch number 14
#  Current loss 1.0518888235092163
#
# Epoch number 14
#  Current loss 1.2216747999191284
#
# Epoch number 14
#  Current loss 1.0140082836151123
#
# Epoch number 14
#  Current loss 1.2003166675567627
#
# Epoch number 14
#  Current loss 1.1018249988555908
#
# Epoch number 14
#  Current loss 1.1020512580871582
#
# Epoch number 14
#  Current loss 1.154937505722046
#
# Epoch number 14
#  Current loss 1.191957950592041
#
# Epoch number 14
#  Current loss 1.2917332649230957
#
# Epoch number 14
#  Current loss 1.386946678161621
#
# Epoch number 14
#  Current loss 1.2965489625930786
#
# Epoch number 14
#  Current loss 0.9795641303062439
#
# Epoch number 14
#  Current loss 1.1220978498458862
#
# Epoch number 15
#  Current loss 1.2157522439956665
#
# Epoch number 15
#  Current loss 1.2335782051086426
#
# Epoch number 15
#  Current loss 1.2573626041412354
#
# Epoch number 15
#  Current loss 1.1296055316925049
#
# Epoch number 15
#  Current loss 1.275620698928833
#
# Epoch number 15
#  Current loss 1.087378740310669
#
# Epoch number 15
#  Current loss 1.1422219276428223
#
# Epoch number 15
#  Current loss 1.1931037902832031
#
# Epoch number 15
#  Current loss 1.247859239578247
#
# Epoch number 15
#  Current loss 1.2125968933105469
#
# Epoch number 15
#  Current loss 1.0416374206542969
#
# Epoch number 15
#  Current loss 1.289536714553833
#
# Epoch number 15
#  Current loss 1.0798490047454834
#
# Epoch number 15
#  Current loss 1.3140547275543213
#
# Epoch number 15
#  Current loss 1.2237412929534912
#
# Epoch number 16
#  Current loss 1.1179988384246826
#
# Epoch number 16
#  Current loss 1.3388174772262573
#
# Epoch number 16
#  Current loss 1.1426787376403809
#
# Epoch number 16
#  Current loss 1.0760440826416016
#
# Epoch number 16
#  Current loss 1.6582775115966797
#
# Epoch number 16
#  Current loss 1.105117678642273
#
# Epoch number 16
#  Current loss 1.3723350763320923
#
# Epoch number 16
#  Current loss 1.773017168045044
#
# Epoch number 16
#  Current loss 0.7636168003082275
#
# Epoch number 16
#  Current loss 1.1553024053573608
#
# Epoch number 16
#  Current loss 1.2281957864761353
#
# Epoch number 16
#  Current loss 1.519580602645874
#
# Epoch number 16
#  Current loss 1.1990538835525513
#
# Epoch number 16
#  Current loss 1.227803349494934
#
# Epoch number 16
#  Current loss 1.2224466800689697
#
# Epoch number 17
#  Current loss 1.2189440727233887
#
# Epoch number 17
#  Current loss 1.3411461114883423
#
# Epoch number 17
#  Current loss 1.1797112226486206
#
# Epoch number 17
#  Current loss 1.2822023630142212
#
# Epoch number 17
#  Current loss 1.9733887910842896
#
# Epoch number 17
#  Current loss 1.3641209602355957
#
# Epoch number 17
#  Current loss 1.416060209274292
#
# Epoch number 17
#  Current loss 1.364497423171997
#
# Epoch number 17
#  Current loss 1.1464273929595947
#
# Epoch number 17
#  Current loss 1.1837904453277588
#
# Epoch number 17
#  Current loss 1.3702105283737183
#
# Epoch number 17
#  Current loss 1.504191517829895
#
# Epoch number 17
#  Current loss 1.1483182907104492
#
# Epoch number 17
#  Current loss 1.2422478199005127
#
# Epoch number 17
#  Current loss 1.1977229118347168
#
# Epoch number 18
#  Current loss 1.3853638172149658
#
# Epoch number 18
#  Current loss 1.1182361841201782
#
# Epoch number 18
#  Current loss 1.4056084156036377
#
# Epoch number 18
#  Current loss 1.2115223407745361
#
# Epoch number 18
#  Current loss 1.3276275396347046
#
# Epoch number 18
#  Current loss 1.0820454359054565
#
# Epoch number 18
#  Current loss 1.324608564376831
#
# Epoch number 18
#  Current loss 1.1527626514434814
#
# Epoch number 18
#  Current loss 0.8127843141555786
#
# Epoch number 18
#  Current loss 0.9258649945259094
#
# Epoch number 18
#  Current loss 1.2018382549285889
#
# Epoch number 18
#  Current loss 1.2741957902908325
#
# Epoch number 18
#  Current loss 1.1499361991882324
#
# Epoch number 18
#  Current loss 1.167502999305725
#
# Epoch number 18
#  Current loss 1.2082409858703613
#
# Epoch number 19
#  Current loss 1.0844485759735107
#
# Epoch number 19
#  Current loss 1.184143304824829
#
# Epoch number 19
#  Current loss 1.12716805934906
#
# Epoch number 19
#  Current loss 1.2880818843841553
#
# Epoch number 19
#  Current loss 1.3637325763702393
#
# Epoch number 19
#  Current loss 1.2004477977752686
#
# Epoch number 19
#  Current loss 1.162219762802124
#
# Epoch number 19
#  Current loss 1.0947679281234741
#
# Epoch number 19
#  Current loss 1.1887586116790771
#
# Epoch number 19
#  Current loss 1.2588205337524414
#
# Epoch number 19
#  Current loss 1.2543679475784302
#
# Epoch number 19
#  Current loss 1.3296711444854736
#
# Epoch number 19
#  Current loss 1.2148914337158203
#
# Epoch number 19
#  Current loss 0.9652981758117676
#
# Epoch number 19
#  Current loss 0.9597023129463196
#
# Epoch number 20
#  Current loss 1.365619421005249
#
# Epoch number 20
#  Current loss 1.2955231666564941
#
# Epoch number 20
#  Current loss 1.3469562530517578
#
# Epoch number 20
#  Current loss 1.4787755012512207
#
# Epoch number 20
#  Current loss 1.267311453819275
#
# Epoch number 20
#  Current loss 1.1475449800491333
#
# Epoch number 20
#  Current loss 0.9633908867835999
#
# Epoch number 20
#  Current loss 1.5023059844970703
#
# Epoch number 20
#  Current loss 1.2572977542877197
#
# Epoch number 20
#  Current loss 1.1996192932128906
#
# Epoch number 20
#  Current loss 1.214832067489624
#
# Epoch number 20
#  Current loss 1.7002581357955933
#
# Epoch number 20
#  Current loss 0.9737281799316406
#
# Epoch number 20
#  Current loss 1.6234586238861084
#
# Epoch number 20
#  Current loss 1.0261671543121338
#
# Epoch number 21
#  Current loss 1.6831470727920532
#
# Epoch number 21
#  Current loss 1.2789950370788574
#
# Epoch number 21
#  Current loss 0.9637266397476196
#
# Epoch number 21
#  Current loss 1.0704905986785889
#
# Epoch number 21
#  Current loss 1.3532278537750244
#
# Epoch number 21
#  Current loss 1.1158168315887451
#
# Epoch number 21
#  Current loss 1.211787462234497
#
# Epoch number 21
#  Current loss 1.3518292903900146
#
# Epoch number 21
#  Current loss 1.296915054321289
#
# Epoch number 21
#  Current loss 1.108237385749817
#
# Epoch number 21
#  Current loss 1.3054029941558838
#
# Epoch number 21
#  Current loss 1.5545909404754639
#
# Epoch number 21
#  Current loss 1.3824114799499512
#
# Epoch number 21
#  Current loss 1.2075347900390625
#
# Epoch number 21
#  Current loss 1.1960153579711914
#
# Epoch number 22
#  Current loss 1.2552227973937988
#
# Epoch number 22
#  Current loss 1.1612526178359985
#
# Epoch number 22
#  Current loss 1.2019460201263428
#
# Epoch number 22
#  Current loss 1.2050291299819946
#
# Epoch number 22
#  Current loss 1.184144139289856
#
# Epoch number 22
#  Current loss 1.2761445045471191
#
# Epoch number 22
#  Current loss 1.7075138092041016
#
# Epoch number 22
#  Current loss 1.4007041454315186
#
# Epoch number 22
#  Current loss 1.1174039840698242
#
# Epoch number 22
#  Current loss 1.0192437171936035
#
# Epoch number 22
#  Current loss 1.1217167377471924
#
# Epoch number 22
#  Current loss 1.2360212802886963
#
# Epoch number 22
#  Current loss 1.3935614824295044
#
# Epoch number 22
#  Current loss 1.359642744064331
#
# Epoch number 22
#  Current loss 1.2895957231521606
#
# Epoch number 23
#  Current loss 1.2399163246154785
#
# Epoch number 23
#  Current loss 1.0939408540725708
#
# Epoch number 23
#  Current loss 1.3379230499267578
#
# Epoch number 23
#  Current loss 1.201959252357483
#
# Epoch number 23
#  Current loss 1.2398593425750732
#
# Epoch number 23
#  Current loss 1.3323445320129395
#
# Epoch number 23
#  Current loss 1.1459333896636963
#
# Epoch number 23
#  Current loss 1.478666067123413
#
# Epoch number 23
#  Current loss 1.261032223701477
#
# Epoch number 23
#  Current loss 1.1855473518371582
#
# Epoch number 23
#  Current loss 1.0118892192840576
#
# Epoch number 23
#  Current loss 0.9401976466178894
#
# Epoch number 23
#  Current loss 1.355780839920044
#
# Epoch number 23
#  Current loss 1.182826280593872
#
# Epoch number 23
#  Current loss 1.301397681236267
#
# Epoch number 24
#  Current loss 1.0175774097442627
#
# Epoch number 24
#  Current loss 1.1706465482711792
#
# Epoch number 24
#  Current loss 1.263927698135376
#
# Epoch number 24
#  Current loss 1.324410319328308
#
# Epoch number 24
#  Current loss 1.2091877460479736
#
# Epoch number 24
#  Current loss 1.2611987590789795
#
# Epoch number 24
#  Current loss 1.135217547416687
#
# Epoch number 24
#  Current loss 1.1603155136108398
#
# Epoch number 24
#  Current loss 1.2841224670410156
#
# Epoch number 24
#  Current loss 0.9832218885421753
#
# Epoch number 24
#  Current loss 1.1749544143676758
#
# Epoch number 24
#  Current loss 1.4730055332183838
#
# Epoch number 24
#  Current loss 1.167922019958496
#
# Epoch number 24
#  Current loss 1.5340321063995361
#
# Epoch number 24
#  Current loss 1.1675307750701904
#
# Epoch number 25
#  Current loss 1.1439883708953857
#
# Epoch number 25
#  Current loss 1.0894865989685059
#
# Epoch number 25
#  Current loss 1.0870872735977173
#
# Epoch number 25
#  Current loss 1.2831019163131714
#
# Epoch number 25
#  Current loss 1.2974272966384888
#
# Epoch number 25
#  Current loss 1.0790650844573975
#
# Epoch number 25
#  Current loss 1.3665231466293335
#
# Epoch number 25
#  Current loss 1.1022053956985474
#
# Epoch number 25
#  Current loss 1.2854201793670654
#
# Epoch number 25
#  Current loss 1.156618356704712
#
# Epoch number 25
#  Current loss 1.3380553722381592
#
# Epoch number 25
#  Current loss 1.3413605690002441
#
# Epoch number 25
#  Current loss 1.13749098777771
#
# Epoch number 25
#  Current loss 1.3759006261825562
#
# Epoch number 25
#  Current loss 1.2061052322387695
#
# Epoch number 26
#  Current loss 1.849795937538147
#
# Epoch number 26
#  Current loss 1.2461585998535156
#
# Epoch number 26
#  Current loss 1.2330044507980347
#
# Epoch number 26
#  Current loss 1.1992616653442383
#
# Epoch number 26
#  Current loss 0.9411541819572449
#
# Epoch number 26
#  Current loss 0.9614231586456299
#
# Epoch number 26
#  Current loss 1.185978889465332
#
# Epoch number 26
#  Current loss 1.117063045501709
#
# Epoch number 26
#  Current loss 1.3071558475494385
#
# Epoch number 26
#  Current loss 1.0009901523590088
#
# Epoch number 26
#  Current loss 1.2249401807785034
#
# Epoch number 26
#  Current loss 1.2951405048370361
#
# Epoch number 26
#  Current loss 1.194706916809082
#
# Epoch number 26
#  Current loss 1.2545411586761475
#
# Epoch number 26
#  Current loss 1.2322461605072021
#
# Epoch number 27
#  Current loss 1.448296070098877
#
# Epoch number 27
#  Current loss 1.0364691019058228
#
# Epoch number 27
#  Current loss 1.2307565212249756
#
# Epoch number 27
#  Current loss 1.1059592962265015
#
# Epoch number 27
#  Current loss 1.2704577445983887
#
# Epoch number 27
#  Current loss 1.0382475852966309
#
# Epoch number 27
#  Current loss 1.2477113008499146
#
# Epoch number 27
#  Current loss 0.8960705995559692
#
# Epoch number 27
#  Current loss 1.195821762084961
#
# Epoch number 27
#  Current loss 1.181823968887329
#
# Epoch number 27
#  Current loss 1.1051170825958252
#
# Epoch number 27
#  Current loss 1.6326212882995605
#
# Epoch number 27
#  Current loss 1.2424678802490234
#
# Epoch number 27
#  Current loss 1.2610416412353516
#
# Epoch number 27
#  Current loss 1.1055309772491455
#
# Epoch number 28
#  Current loss 1.0820832252502441
#
# Epoch number 28
#  Current loss 1.1283161640167236
#
# Epoch number 28
#  Current loss 1.3787345886230469
#
# Epoch number 28
#  Current loss 1.0747215747833252
#
# Epoch number 28
#  Current loss 0.8820703029632568
#
# Epoch number 28
#  Current loss 1.2468352317810059
#
# Epoch number 28
#  Current loss 1.2149198055267334
#
# Epoch number 28
#  Current loss 1.28829026222229
#
# Epoch number 28
#  Current loss 1.3250858783721924
#
# Epoch number 28
#  Current loss 1.0731127262115479
#
# Epoch number 28
#  Current loss 1.1495860815048218
#
# Epoch number 28
#  Current loss 0.8631312251091003
#
# Epoch number 28
#  Current loss 1.2356617450714111
#
# Epoch number 28
#  Current loss 1.3330719470977783
#
# Epoch number 28
#  Current loss 1.6524384021759033
#
# Epoch number 29
#  Current loss 1.4281389713287354
#
# Epoch number 29
#  Current loss 1.2211103439331055
#
# Epoch number 29
#  Current loss 1.216660737991333
#
# Epoch number 29
#  Current loss 1.2509286403656006
#
# Epoch number 29
#  Current loss 1.1575605869293213
#
# Epoch number 29
#  Current loss 1.1840572357177734
#
# Epoch number 29
#  Current loss 1.2331914901733398
#
# Epoch number 29
#  Current loss 1.0240991115570068
#
# Epoch number 29
#  Current loss 1.147698998451233
#
# Epoch number 29
#  Current loss 1.1905758380889893
#
# Epoch number 29
#  Current loss 1.1377010345458984
#
# Epoch number 29
#  Current loss 1.1192212104797363
#
# Epoch number 29
#  Current loss 1.2730602025985718
#
# Epoch number 29
#  Current loss 1.3947218656539917
#
# Epoch number 29
#  Current loss 1.366114616394043
#
# Epoch number 30
#  Current loss 1.1539901494979858
#
# Epoch number 30
#  Current loss 1.3185900449752808
#
# Epoch number 30
#  Current loss 1.1881667375564575
#
# Epoch number 30
#  Current loss 1.2461357116699219
#
# Epoch number 30
#  Current loss 1.3685998916625977
#
# Epoch number 30
#  Current loss 1.2893915176391602
#
# Epoch number 30
#  Current loss 1.0832760334014893
#
# Epoch number 30
#  Current loss 1.1907360553741455
#
# Epoch number 30
#  Current loss 1.3108866214752197
#
# Epoch number 30
#  Current loss 0.9802545309066772
#
# Epoch number 30
#  Current loss 1.2253899574279785
#
# Epoch number 30
#  Current loss 1.146740436553955
#
# Epoch number 30
#  Current loss 1.2374155521392822
#
# Epoch number 30
#  Current loss 1.192981481552124
#
# Epoch number 30
#  Current loss 1.1406397819519043
#
# Epoch number 31
#  Current loss 1.1380202770233154
#
# Epoch number 31
#  Current loss 1.4229567050933838
#
# Epoch number 31
#  Current loss 1.1467454433441162
#
# Epoch number 31
#  Current loss 1.0487877130508423
#
# Epoch number 31
#  Current loss 1.1638569831848145
#
# Epoch number 31
#  Current loss 1.0160651206970215
#
# Epoch number 31
#  Current loss 1.3865352869033813
#
# Epoch number 31
#  Current loss 1.305107593536377
#
# Epoch number 31
#  Current loss 1.3667056560516357
#
# Epoch number 31
#  Current loss 1.4082581996917725
#
# Epoch number 31
#  Current loss 1.4834113121032715
#
# Epoch number 31
#  Current loss 1.27351713180542
#
# Epoch number 31
#  Current loss 1.1395776271820068
#
# Epoch number 31
#  Current loss 1.1425271034240723
#
# Epoch number 31
#  Current loss 1.1540336608886719
#
# Epoch number 32
#  Current loss 1.1069726943969727
#
# Epoch number 32
#  Current loss 1.0948865413665771
#
# Epoch number 32
#  Current loss 1.2237342596054077
#
# Epoch number 32
#  Current loss 1.5623142719268799
#
# Epoch number 32
#  Current loss 1.1784566640853882
#
# Epoch number 32
#  Current loss 1.1172572374343872
#
# Epoch number 32
#  Current loss 1.2727887630462646
#
# Epoch number 32
#  Current loss 1.119086742401123
#
# Epoch number 32
#  Current loss 1.2738959789276123
#
# Epoch number 32
#  Current loss 1.1743484735488892
#
# Epoch number 32
#  Current loss 1.1736016273498535
#
# Epoch number 32
#  Current loss 1.368455171585083
#
# Epoch number 32
#  Current loss 1.1463561058044434
#
# Epoch number 32
#  Current loss 1.025538682937622
#
# Epoch number 32
#  Current loss 1.1732590198516846
#
# Epoch number 33
#  Current loss 1.095261812210083
#
# Epoch number 33
#  Current loss 1.0522468090057373
#
# Epoch number 33
#  Current loss 1.2315821647644043
#
# Epoch number 33
#  Current loss 1.399783968925476
#
# Epoch number 33
#  Current loss 0.9232984781265259
#
# Epoch number 33
#  Current loss 1.065713882446289
#
# Epoch number 33
#  Current loss 1.469752550125122
#
# Epoch number 33
#  Current loss 1.18000066280365
#
# Epoch number 33
#  Current loss 1.2017550468444824
#
# Epoch number 33
#  Current loss 1.4010038375854492
#
# Epoch number 33
#  Current loss 1.1596307754516602
#
# Epoch number 33
#  Current loss 1.2090948820114136
#
# Epoch number 33
#  Current loss 1.0070998668670654
#
# Epoch number 33
#  Current loss 1.2728986740112305
#
# Epoch number 33
#  Current loss 1.161158800125122
#
# Epoch number 34
#  Current loss 1.1756937503814697
#
# Epoch number 34
#  Current loss 0.8862711191177368
#
# Epoch number 34
#  Current loss 1.1870801448822021
#
# Epoch number 34
#  Current loss 1.1223708391189575
#
# Epoch number 34
#  Current loss 1.1459262371063232
#
# Epoch number 34
#  Current loss 0.9304208755493164
#
# Epoch number 34
#  Current loss 1.2133936882019043
#
# Epoch number 34
#  Current loss 1.3724403381347656
#
# Epoch number 34
#  Current loss 1.2077363729476929
#
# Epoch number 34
#  Current loss 1.0428040027618408
#
# Epoch number 34
#  Current loss 1.1506707668304443
#
# Epoch number 34
#  Current loss 1.0578291416168213
#
# Epoch number 34
#  Current loss 1.2654895782470703
#
# Epoch number 34
#  Current loss 1.2823951244354248
#
# Epoch number 34
#  Current loss 1.1090384721755981
#
# Epoch number 35
#  Current loss 1.2476167678833008
#
# Epoch number 35
#  Current loss 1.0918095111846924
#
# Epoch number 35
#  Current loss 1.1955593824386597
#
# Epoch number 35
#  Current loss 1.0953731536865234
#
# Epoch number 35
#  Current loss 1.0185149908065796
#
# Epoch number 35
#  Current loss 1.1268366575241089
#
# Epoch number 35
#  Current loss 1.1966147422790527
#
# Epoch number 35
#  Current loss 0.9733952283859253
#
# Epoch number 35
#  Current loss 1.1952117681503296
#
# Epoch number 35
#  Current loss 0.9998350143432617
#
# Epoch number 35
#  Current loss 1.229743480682373
#
# Epoch number 35
#  Current loss 1.2663654088974
#
# Epoch number 35
#  Current loss 1.3859822750091553
#
# Epoch number 35
#  Current loss 1.1657767295837402
#
# Epoch number 35
#  Current loss 1.200430154800415
#
# Epoch number 36
#  Current loss 1.1603015661239624
#
# Epoch number 36
#  Current loss 1.1891653537750244
#
# Epoch number 36
#  Current loss 1.4219627380371094
#
# Epoch number 36
#  Current loss 1.092032790184021
#
# Epoch number 36
#  Current loss 1.2499386072158813
#
# Epoch number 36
#  Current loss 1.1697598695755005
#
# Epoch number 36
#  Current loss 1.4218475818634033
#
# Epoch number 36
#  Current loss 1.1430493593215942
#
# Epoch number 36
#  Current loss 1.6796846389770508
#
# Epoch number 36
#  Current loss 1.1256937980651855
#
# Epoch number 36
#  Current loss 1.2705062627792358
#
# Epoch number 36
#  Current loss 1.15328049659729
#
# Epoch number 36
#  Current loss 1.2675731182098389
#
# Epoch number 36
#  Current loss 1.4857137203216553
#
# Epoch number 36
#  Current loss 1.0561407804489136
#
# Epoch number 37
#  Current loss 1.2176332473754883
#
# Epoch number 37
#  Current loss 1.1889240741729736
#
# Epoch number 37
#  Current loss 1.1827831268310547
#
# Epoch number 37
#  Current loss 1.2236301898956299
#
# Epoch number 37
#  Current loss 1.079401969909668
#
# Epoch number 37
#  Current loss 1.3022431135177612
#
# Epoch number 37
#  Current loss 1.061903715133667
#
# Epoch number 37
#  Current loss 1.1607974767684937
#
# Epoch number 37
#  Current loss 1.0376003980636597
#
# Epoch number 37
#  Current loss 1.2209782600402832
#
# Epoch number 37
#  Current loss 1.530407428741455
#
# Epoch number 37
#  Current loss 1.05875825881958
#
# Epoch number 37
#  Current loss 1.0993890762329102
#
# Epoch number 37
#  Current loss 1.031683087348938
#
# Epoch number 37
#  Current loss 1.172654390335083
#
# Epoch number 38
#  Current loss 1.3749043941497803
#
# Epoch number 38
#  Current loss 1.036042332649231
#
# Epoch number 38
#  Current loss 1.187707781791687
#
# Epoch number 38
#  Current loss 1.497631311416626
#
# Epoch number 38
#  Current loss 1.0627665519714355
#
# Epoch number 38
#  Current loss 1.2556703090667725
#
# Epoch number 38
#  Current loss 1.1382167339324951
#
# Epoch number 38
#  Current loss 2.010435104370117
#
# Epoch number 38
#  Current loss 1.2567253112792969
#
# Epoch number 38
#  Current loss 1.2985137701034546
#
# Epoch number 38
#  Current loss 1.0372792482376099
#
# Epoch number 38
#  Current loss 1.2544679641723633
#
# Epoch number 38
#  Current loss 1.3574243783950806
#
# Epoch number 38
#  Current loss 0.9883623719215393
#
# Epoch number 38
#  Current loss 1.652103304862976
#
# Epoch number 39
#  Current loss 1.138167381286621
#
# Epoch number 39
#  Current loss 1.1943864822387695
#
# Epoch number 39
#  Current loss 0.9913018345832825
#
# Epoch number 39
#  Current loss 1.240363597869873
#
# Epoch number 39
#  Current loss 1.3779122829437256
#
# Epoch number 39
#  Current loss 1.131772756576538
#
# Epoch number 39
#  Current loss 1.2273179292678833
#
# Epoch number 39
#  Current loss 1.0637662410736084
#
# Epoch number 39
#  Current loss 1.1035561561584473
#
# Epoch number 39
#  Current loss 1.1343698501586914
#
# Epoch number 39
#  Current loss 1.1067118644714355
#
# Epoch number 39
#  Current loss 1.638071894645691
#
# Epoch number 39
#  Current loss 1.2415621280670166
#
# Epoch number 39
#  Current loss 1.1535332202911377
#
# Epoch number 39
#  Current loss 1.1845778226852417
#
# Epoch number 40
#  Current loss 1.212464690208435
#
# Epoch number 40
#  Current loss 1.350620985031128
#
# Epoch number 40
#  Current loss 1.4797453880310059
#
# Epoch number 40
#  Current loss 1.1065263748168945
#
# Epoch number 40
#  Current loss 1.4251976013183594
#
# Epoch number 40
#  Current loss 1.2233004570007324
#
# Epoch number 40
#  Current loss 1.1609773635864258
#
# Epoch number 40
#  Current loss 1.1349928379058838
#
# Epoch number 40
#  Current loss 1.0159375667572021
#
# Epoch number 40
#  Current loss 1.4611930847167969
#
# Epoch number 40
#  Current loss 1.1834588050842285
#
# Epoch number 40
#  Current loss 1.3109924793243408
#
# Epoch number 40
#  Current loss 1.0412927865982056
#
# Epoch number 40
#  Current loss 1.1265649795532227
#
# Epoch number 40
#  Current loss 1.186897873878479
#
# Epoch number 41
#  Current loss 1.2695107460021973
#
# Epoch number 41
#  Current loss 1.15706467628479
#
# Epoch number 41
#  Current loss 1.329155683517456
#
# Epoch number 41
#  Current loss 1.1332123279571533
#
# Epoch number 41
#  Current loss 1.285884141921997
#
# Epoch number 41
#  Current loss 1.369168758392334
#
# Epoch number 41
#  Current loss 1.0974699258804321
#
# Epoch number 41
#  Current loss 1.17228364944458
#
# Epoch number 41
#  Current loss 1.222940444946289
#
# Epoch number 41
#  Current loss 1.0948381423950195
#
# Epoch number 41
#  Current loss 0.9731763601303101
#
# Epoch number 41
#  Current loss 1.1579525470733643
#
# Epoch number 41
#  Current loss 1.2449623346328735
#
# Epoch number 41
#  Current loss 1.2588523626327515
#
# Epoch number 41
#  Current loss 1.1404476165771484
#
# Epoch number 42
#  Current loss 1.1981186866760254
#
# Epoch number 42
#  Current loss 1.281437873840332
#
# Epoch number 42
#  Current loss 1.1988701820373535
#
# Epoch number 42
#  Current loss 1.1183944940567017
#
# Epoch number 42
#  Current loss 1.133009910583496
#
# Epoch number 42
#  Current loss 1.1075468063354492
#
# Epoch number 42
#  Current loss 1.167860507965088
#
# Epoch number 42
#  Current loss 1.3335833549499512
#
# Epoch number 42
#  Current loss 1.249205231666565
#
# Epoch number 42
#  Current loss 1.0721855163574219
#
# Epoch number 42
#  Current loss 0.9935771822929382
#
# Epoch number 42
#  Current loss 1.2117507457733154
#
# Epoch number 42
#  Current loss 1.307030200958252
#
# Epoch number 42
#  Current loss 1.1681320667266846
#
# Epoch number 42
#  Current loss 1.182775855064392
#
# Epoch number 43
#  Current loss 1.2841312885284424
#
# Epoch number 43
#  Current loss 1.1646026372909546
#
# Epoch number 43
#  Current loss 1.1259727478027344
#
# Epoch number 43
#  Current loss 1.161852240562439
#
# Epoch number 43
#  Current loss 1.3685530424118042
#
# Epoch number 43
#  Current loss 1.4567797183990479
#
# Epoch number 43
#  Current loss 1.1567533016204834
#
# Epoch number 43
#  Current loss 1.2661837339401245
#
# Epoch number 43
#  Current loss 1.2903863191604614
#
# Epoch number 43
#  Current loss 1.0505393743515015
#
# Epoch number 43
#  Current loss 1.1844251155853271
#
# Epoch number 43
#  Current loss 1.1427648067474365
#
# Epoch number 43
#  Current loss 1.221733570098877
#
# Epoch number 43
#  Current loss 1.3040168285369873
#
# Epoch number 43
#  Current loss 1.311375379562378
#
# Epoch number 44
#  Current loss 1.0754339694976807
#
# Epoch number 44
#  Current loss 1.5829507112503052
#
# Epoch number 44
#  Current loss 1.1618845462799072
#
# Epoch number 44
#  Current loss 1.1303699016571045
#
# Epoch number 44
#  Current loss 0.9689791798591614
#
# Epoch number 44
#  Current loss 1.098894476890564
#
# Epoch number 44
#  Current loss 1.0427358150482178
#
# Epoch number 44
#  Current loss 1.1945970058441162
#
# Epoch number 44
#  Current loss 1.3797109127044678
#
# Epoch number 44
#  Current loss 1.0029609203338623
#
# Epoch number 44
#  Current loss 1.1704248189926147
#
# Epoch number 44
#  Current loss 1.1836129426956177
#
# Epoch number 44
#  Current loss 1.4056819677352905
#
# Epoch number 44
#  Current loss 1.2439966201782227
#
# Epoch number 44
#  Current loss 1.2488082647323608
#
# Epoch number 45
#  Current loss 1.2352784872055054
#
# Epoch number 45
#  Current loss 1.218241810798645
#
# Epoch number 45
#  Current loss 1.112431287765503
#
# Epoch number 45
#  Current loss 1.2455801963806152
#
# Epoch number 45
#  Current loss 1.1656421422958374
#
# Epoch number 45
#  Current loss 1.0073153972625732
#
# Epoch number 45
#  Current loss 1.2898446321487427
#
# Epoch number 45
#  Current loss 1.4900760650634766
#
# Epoch number 45
#  Current loss 0.9711899161338806
#
# Epoch number 45
#  Current loss 1.1212158203125
#
# Epoch number 45
#  Current loss 1.2541210651397705
#
# Epoch number 45
#  Current loss 1.1286909580230713
#
# Epoch number 45
#  Current loss 1.3158555030822754
#
# Epoch number 45
#  Current loss 1.2061984539031982
#
# Epoch number 45
#  Current loss 1.341477632522583
#
# Epoch number 46
#  Current loss 1.2535699605941772
#
# Epoch number 46
#  Current loss 1.3516566753387451
#
# Epoch number 46
#  Current loss 1.341214895248413
#
# Epoch number 46
#  Current loss 1.2520766258239746
#
# Epoch number 46
#  Current loss 1.4097189903259277
#
# Epoch number 46
#  Current loss 1.0867083072662354
#
# Epoch number 46
#  Current loss 1.228330135345459
#
# Epoch number 46
#  Current loss 1.248433232307434
#
# Epoch number 46
#  Current loss 1.0506486892700195
#
# Epoch number 46
#  Current loss 1.150086522102356
#
# Epoch number 46
#  Current loss 1.1245529651641846
#
# Epoch number 46
#  Current loss 1.2297532558441162
#
# Epoch number 46
#  Current loss 1.183668613433838
#
# Epoch number 46
#  Current loss 1.5832555294036865
#
# Epoch number 46
#  Current loss 1.068425178527832
#
# Epoch number 47
#  Current loss 1.1470999717712402
#
# Epoch number 47
#  Current loss 1.0889546871185303
#
# Epoch number 47
#  Current loss 1.1727569103240967
#
# Epoch number 47
#  Current loss 0.9696149230003357
#
# Epoch number 47
#  Current loss 1.1595861911773682
#
# Epoch number 47
#  Current loss 1.0690429210662842
#
# Epoch number 47
#  Current loss 1.1860631704330444
#
# Epoch number 47
#  Current loss 1.052973747253418
#
# Epoch number 47
#  Current loss 1.1387879848480225
#
# Epoch number 47
#  Current loss 1.1101620197296143
#
# Epoch number 47
#  Current loss 1.1600992679595947
#
# Epoch number 47
#  Current loss 1.1159355640411377
#
# Epoch number 47
#  Current loss 1.1759268045425415
#
# Epoch number 47
#  Current loss 1.036231279373169
#
# Epoch number 47
#  Current loss 1.1707165241241455
#
# Epoch number 48
#  Current loss 1.2466450929641724
#
# Epoch number 48
#  Current loss 1.1819342374801636
#
# Epoch number 48
#  Current loss 1.2246434688568115
#
# Epoch number 48
#  Current loss 1.159325361251831
#
# Epoch number 48
#  Current loss 1.1551135778427124
#
# Epoch number 48
#  Current loss 1.2666568756103516
#
# Epoch number 48
#  Current loss 1.060019612312317
#
# Epoch number 48
#  Current loss 1.2190990447998047
#
# Epoch number 48
#  Current loss 1.4772372245788574
#
# Epoch number 48
#  Current loss 1.0896122455596924
#
# Epoch number 48
#  Current loss 1.1367826461791992
#
# Epoch number 48
#  Current loss 1.092872977256775
#
# Epoch number 48
#  Current loss 1.3341137170791626
#
# Epoch number 48
#  Current loss 1.1729328632354736
#
# Epoch number 48
#  Current loss 1.3716273307800293
#
# Epoch number 49
#  Current loss 1.2095088958740234
#
# Epoch number 49
#  Current loss 1.0801451206207275
#
# Epoch number 49
#  Current loss 1.2906198501586914
#
# Epoch number 49
#  Current loss 1.1263582706451416
#
# Epoch number 49
#  Current loss 1.2565789222717285
#
# Epoch number 49
#  Current loss 1.0892119407653809
#
# Epoch number 49
#  Current loss 1.0690557956695557
#
# Epoch number 49
#  Current loss 1.2018237113952637
#
# Epoch number 49
#  Current loss 1.2125535011291504
#
# Epoch number 49
#  Current loss 1.2436463832855225
#
# Epoch number 49
#  Current loss 1.2153820991516113
#
# Epoch number 49
#  Current loss 1.9111757278442383
#
# Epoch number 49
#  Current loss 1.2669956684112549
#
# Epoch number 49
#  Current loss 1.3778889179229736
#
# Epoch number 49
#  Current loss 1.3296512365341187
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("model.pt"))
# Out:
# <All keys matched successfully>

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1,output2 = model(x0.to(device),x1.to(device))
  eucledian_distance = F.pairwise_distance(output1, output2)
  if label==list_0:
    label="Orginial"
  else:
    label="Forged"
  imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  counter=counter+1
  if counter ==20:
     break
